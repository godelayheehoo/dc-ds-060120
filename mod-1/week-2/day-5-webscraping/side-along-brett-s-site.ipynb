# %% [markdown]
# -look for where images are tiny
# -look for where product descriptions are mssed up.

# %%
import requests
headers= {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
#headers from stackexchange
page = requests.get("http://bangmusicinc.com",headers=headers)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n    \n<!-- Global site tag (gtag.js) - Google Analytics -->\r\n\r\n\n\t<link rel="icon" type="image/x-icon" href="/favicon.ico">\n    <title>Home</title>\n    <meta name="description" content="">\n\t\n\t<link rel="canonical" href="https://www.bangmusicinc.com/">\n\t\n\t\n\t<!-- BOOTSTRAP START -->\n    <meta charset="utf-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge"><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"d60c52fc57",applicationID:"7339757"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var i=n[t]={exports:{}};e[t][0].call(i.exports,function(n){var i=e[t][1][n];return r(i||n)},i,i.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<t.length;i++)r(t[i]);return r}({1:[function(e,n,t){function r(){}function i(e,n,t){return function(){return o(e,[u.now()].concat(f(arguments)),n?null:this,t),n?void 0:this}}var
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <title>
#    Home
#   </title>
#   <meta content="" name="description"/>
#   <link href="https://www.bangmusicinc.com/" rel="canonical"/>
#   <!-- BOOTSTRAP START -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
# ...

# %%
list(soup.children)
# Out:
# ['html', '\n', <html lang="en">
#  <head>
#  <!-- Global site tag (gtag.js) - Google Analytics -->
#  <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#  <title>Home</title>
#  <meta content="" name="description"/>
#  <link href="https://www.bangmusicinc.com/" rel="canonical"/>
#  <!-- BOOTSTRAP START -->
#  <meta charset="utf-8"/>
# ...

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_check_markup_is_url',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
# ...

# %% [markdown]
# I want something like "url contains /shop/"
#
# [s for s in soup.find_all('a') if '/shop/' in str(s)]

# %% [markdown]
# Alternatively:

# %%
soup.select("a[href*=shop]")
#Not sure how to get the slashes in there.
# Out:
# [<a href="https://www.bangmusicinc.com/shop.htm">Shop All</a>,
#  <a href="javascript:void(window.open('https://reverb.com/shop/bang-music-inc'));">Reverb Store</a>,
#  <a href="https://www.bangmusicinc.com/shop/Amplifiers.htm"><img class="cItemImage" src="https://media.rainpos.com/9176/blackstar_test.jpg"/></a>,
#  <a href="https://www.bangmusicinc.com/shop/Band.htm"><img class="cItemImage" src="https://media.rainpos.com/9176/bandinstruments_20190418172631.jpg"/></a>,
#  <a href="https://www.bangmusicinc.com/shop/Cables.htm"><img class="cItemImage" src="https://media.rainpos.com/9176/sc10bl_rev.jpg"/></a>,
#  <a href="https://www.bangmusicinc.com/shop/Gifts-and-Accessories.htm"><img class="cItemImage" src="https://media.rainpos.com/9176/planet_waves_pwep_100_ear_plugs.jpg"/></a>,
#  <a href="https://www.bangmusicinc.com/shop/Guitar-Bass-Uke-and-Folk.htm"><img class="cItemImage" src="https://media.rainpos.com/9176/new_3_three_guitar.png"/></a>,
# ...

# %%
shopitems=soup.find_all("a",href=lambda href: href and ".com/shop/" in href and "www" in href)

shopitems[0]
# Out:
# <a href="https://www.bangmusicinc.com/shop/Amplifiers.htm"><img class="cItemImage" src="https://media.rainpos.com/9176/blackstar_test.jpg"/></a>

# %%
dir(shopitems[0])
# Out:
# ['__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contents',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'descendants',
#  'encode',
#  'encode_contents',
# ...

# %%
u=shopitems[0].get('href')

print(u)
print(type(u))
# Out:
# https://www.bangmusicinc.com/shop/Amplifiers.htm
# <class 'str'>

# %%
shop_page_list=[n.get('href') for n in shopitems]
shop_page_list
# Out:
# ['https://www.bangmusicinc.com/shop/Amplifiers.htm',
#  'https://www.bangmusicinc.com/shop/Band.htm',
#  'https://www.bangmusicinc.com/shop/Cables.htm',
#  'https://www.bangmusicinc.com/shop/Gifts-and-Accessories.htm',
#  'https://www.bangmusicinc.com/shop/Guitar-Bass-Uke-and-Folk.htm',
#  'https://www.bangmusicinc.com/shop/Keyboards.htm',
#  'https://www.bangmusicinc.com/shop/Orchestra.htm',
#  'https://www.bangmusicinc.com/shop/Parts.htm',
#  'https://www.bangmusicinc.com/shop/Percussion.htm',
#  'https://www.bangmusicinc.com/shop/Print.htm',
#  'https://www.bangmusicinc.com/shop/Pro-Audio.htm',
#  'https://www.bangmusicinc.com/shop/Software-and-Interfaces.htm',
#  'https://www.bangmusicinc.com/shop/Stands.htm']

# %% [markdown]
# ----------------
# starting work on just first item:
# -----------------

# %%
soup2=BeautifulSoup(
    requests.get(
        shop_page_list[0]
    ,headers=headers
    ).content
    #using headers from above
)

# %%
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <title>
#    Amplifiers
#   </title>
#   <meta content="Amplifiers &amp; Speakers" name="description"/>
#   <link href="https://www.bangmusicinc.com/shop/Amplifiers.htm" rel="canonical"/>
#   <link href="oss.maxcdn.com" rel="dns-prefetch"/>
#   <link href="ajax.googleapis.com" rel="dns-prefetch"/>
#   <!-- BOOTSTRAP START !! -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
# ...

# %% [raw]
# Working with first item:
#
# looks like the "onclick" is an attribute I need to pull from.

# %%
first_first=soup2.find_all("div",class_='cItemDiv')[0]
print(first_first, '\n\n-------')
first_first['onclick'].replace("handleCItemClick('",'').replace("');",'')
# Out:
# <div class="cItemDiv" onclick="handleCItemClick('https://www.bangmusicinc.com/shop/Amplifiers/p/ACOUSTIC-BASS-COMBO-B100C-x46435140.htm');">
# <div align="center" class="cItemImageDiv">
# <!-- <button class="cItemBtn">Check It Out</button> -->
# <span class="cItemImageHelper"></span><a href="https://www.bangmusicinc.com/shop/Amplifiers/p/ACOUSTIC-BASS-COMBO-B100C-x46435140.htm"><img class="cItemImage" src="https://media.rainpos.com/9176/b100c_acoustic_amplification_600x400.jpg"/></a>
# </div>
# <div class="cItemTitleDiv" style="">
# <p class="cItemType">PRODUCT</p>
# <p class="cItemTitle">ACOUSTIC BASS COMBO B100C</p>
# <p class="cItemPrice">$269.99</p>
# </div>
# </div>
#
# -------
# 'https://www.bangmusicinc.com/shop/Amplifiers/p/ACOUSTIC-BASS-COMBO-B100C-x46435140.htm'

# %% [markdown]
# Taking a really stupid, brute-force method here.

# %% [markdown]
# Should really be looking into "navigating the string"
# ------------------

# %%
first_first_page_soup=BeautifulSoup(
    requests.get(
        first_first['onclick'].replace("handleCItemClick('",'').replace("');",'')
    ,headers=headers
    ).content
    #using headers from above
)

# %%
print(first_first_page_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <title>
#    ACOUSTIC BASS COMBO B100C
#   </title>
#   <meta content="" name="description"/>
#   <link href="https://www.bangmusicinc.com/shop/c/p/ACOUSTIC-BASS-COMBO-B100C-x46435140.htm" rel="canonical"/>
#   <link href="oss.maxcdn.com" rel="dns-prefetch"/>
#   <link href="ajax.googleapis.com" rel="dns-prefetch"/>
#   <!-- BOOTSTRAP START !! -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
# ...

# %% [markdown]
# Does brett's web developer have a special business in websites for quilt stores???
#
# Need to open this up to stop it from rendering:
# h1, "product details pricing" spanprice thing,  "Manufacturer Number,   <tr>
# </html>
# <td>
#           <b>
#            Manufacturer #:
#           </b>
#          </td>
#          <td>
#           B100C
#          </td>
#         </tr>"
#
#  <tr>
#          <td>
#           <b>
#            Sku:
#           </b>
#          </td>
#          <td>
#           B100C
#          </td>
#         </tr>
#         <tr>
#
# "ar isFabric46435140 = false;
# var soldInIncrements46435140 = 1;
# var prices46435140 = [];
# var minimumQuantity = 1;prices46435140['0'] = [];
# prices46435140['0']['pslrId'] = 67631783;
# prices46435140['0']['quantity'] = 2;
# prices46435140['0']['reserve'] = 0;
# prices46435140['0']['sku'] = 'B100C';
# prices46435140['0']['weight'] = '0';
# prices46435140['0']['price'] = 269.99;
# prices46435140['0']['salePrice'] = 0.00;
# prices46435140['0']['finalPrice'] = 269.990;
# prices46435140['0']['finalDisplayPrice'] = 269.99;
# prices46435140['0']['isWholesale'] = 0;
# var attributeValues46435140 = [];
#   </script>"
#
#     <img alt="ACOUSTIC BASS COMBO B100C"

# %%
[s.text for s in first_first_page_soup.find_all('h1')]
# Out:
# ['ACOUSTIC BASS COMBO B100C']

# %%
[s['src'] for s in first_first_page_soup.find_all('img', class_="img-responsive",id=lambda x: x and 'product' in x)]
#Very unsure this will always work.
# Out:
# ['https://media.rainpos.com/9176/b100c_acoustic_amplification_600x400.jpg']

# %%
[s['id'].split('Label')[-1] for s in first_first_page_soup.find_all(id=lambda x: x and 'spanPriceLabel' in x)]

#I'm 99% sure this is just some pointer thing but it can't hurt to pull it out.
# Out:
# ['46435140']

# %%
first_first_page_soup.find_all('td')

#Going to assume/hope that it always goes <td><b>thing: .. /> linebreak <td><value>
# Out:
# [<td width="100%"><input id="search_keyword" name="search_keyword" placeholder="Search For |" size="" style="width: 100%; height: 100%; background-color: transparent; border: none; padding-left: 10px;" type="text" value=""/></td>,
#  <td align="right" class="header-form-btn"><button name="image" style="background: none; border: none;" type="image" value="Search"><span class="header-form-btn-text">Search</span> </button></td>,
#  <td nowrap=""><b><span id="spanPriceLabel46435140"></span></b>     </td>,
#  <td><span id="spanPrice46435140"></span> </td>,
#  <td colspan="2"></td>,
#  <td nowrap="">
#  <b>Quantity:</b>
#  						</td>,
#  <td>
#  <input id="maxInteger46435140" type="hidden" value="2"/>
#  <input id="maxFraction46435140" type="hidden" value="0"/>
#  <span id="reserve46435140" style="display:none;color:#f00;">Out of Stock</span>
#  <select id="integer46435140" onchange="checkFabricMinimum(46435140)">
# ...

# %%
[[s,s.parent.parent.findNext('td').text] for s in first_first_page_soup.find_all(text='Manufacturer #:')]

#relying on:
#https://stackoverflow.com/questions/5999747/beautifulsoup-nextsibling
# Out:
# [['Manufacturer #:', 'B100C']]

# %%
[[s,s.parent.parent.findNext('td').text] for s in first_first_page_soup.find_all(text='Sku:')]
# Out:
# [['Sku:', 'B100C']]

# %% [markdown]
# Not all items have descriptions.  I'll go back and add something for that to indicate when nothing is present.
#
# No idea what "pslrId" is.

# %% [markdown]
# Moving down so I can use it again:

# %%
print(first_first_page_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <title>
#    ACOUSTIC BASS COMBO B100C
#   </title>
#   <meta content="" name="description"/>
#   <link href="https://www.bangmusicinc.com/shop/c/p/ACOUSTIC-BASS-COMBO-B100C-x46435140.htm" rel="canonical"/>
#   <link href="oss.maxcdn.com" rel="dns-prefetch"/>
#   <link href="ajax.googleapis.com" rel="dns-prefetch"/>
#   <!-- BOOTSTRAP START !! -->
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
# ...

# %%
import re
pattern=re.compile(r"prices(\S*)\['0'\]\['(.*)'] = (.*);")

u=first_first_page_soup.find_all(text=pattern)

# print(u)
# print(len(u))
# print(type(u))


awful_list=[pattern.findall(n) for n in u]
awful_list
# Out:
# [[('46435140', 'pslrId', '67631783'),
#   ('46435140', 'quantity', '2'),
#   ('46435140', 'reserve', '0'),
#   ('46435140', 'sku', "'B100C'"),
#   ('46435140', 'weight', "'0'"),
#   ('46435140', 'price', '269.99'),
#   ('46435140', 'salePrice', '0.00'),
#   ('46435140', 'finalPrice', '269.990'),
#   ('46435140', 'finalDisplayPrice', '269.99'),
#   ('46435140', 'isWholesale', '0')]]

# %% [markdown]
# So the pattern I want is, using ~~ to represent a join here:
# prices ~~ any number of digits, given by \d ~~ ['0'] ~~ ['something'] ~~ = something ~~ ;
#
# Repeated digits can be done with [\d]* I think.  Using the tester here:
# https://pythex.org/
#
# Ah I can just do \d. That seems... weird.   I think the {} thing is for length though and I'm just importing too much mathematica knowledge?
#
# So far I've got:
#
# prices[\d](.*);
#
#
# Trying to figure out how to get " ['0'] ' to match.
#
# Actuallly I guess just this is fine: (might need to open this up to get the right form)
#
# (.*)\['0'\]\['(.*)'] = (.*);
#
# I don't get why this isn't working.
#
# I'm going to throw myself into a wood shredder.  It's matching any text containing it I think.  I guess it's matching the *tags* (or whatever the right term is) that contains *anything* matching the pattern.  So then run the regex through it?   But then I guess I could just not bother with the initial filter.

# %%
pattern.findall("""
var numAttributes46435140 = '0';
var isFabric46435140 = false;
var soldInIncrements46435140 = 1;
var prices46435140 = [];
var minimumQuantity = 1;prices46435140['0'] = [];
prices46435140['0']['pslrId'] = 67631783;
prices46435140['0']['quantity'] = 2;
prices46435140['0']['reserve'] = 0;
prices46435140['0']['sku'] = 'B100C';
prices46435140['0']['weight'] = '0';
prices46435140['0']['price'] = 269.99;
prices46435140['0']['salePrice'] = 0.00;
prices46435140['0']['finalPrice'] = 269.990;
prices46435140['0']['finalDisplayPrice'] = 269.99;
prices46435140['0']['isWholesale'] = 0;
var attributeValues46435140 = [];
              """)
# Out:
# [('46435140', 'pslrId', '67631783'),
#  ('46435140', 'quantity', '2'),
#  ('46435140', 'reserve', '0'),
#  ('46435140', 'sku', "'B100C'"),
#  ('46435140', 'weight', "'0'"),
#  ('46435140', 'price', '269.99'),
#  ('46435140', 'salePrice', '0.00'),
#  ('46435140', 'finalPrice', '269.990'),
#  ('46435140', 'finalDisplayPrice', '269.99'),
#  ('46435140', 'isWholesale', '0')]

# %%
pattern.match('k')

# %% [markdown]
# I can do the boring part tomorrow, which admittedly means I probably won't be doing it at all.
