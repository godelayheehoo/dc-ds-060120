# %%
import numpy as np
rng=np.random.default_rng()
pts=rng.beta(4,2,5000)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import scipy.stats as st
alpha,beta,loc,scale=st.beta.fit(pts)
print(alpha, beta)
# Out:
# 3.9322418208376266 1.9816184578068698

# %%
st.beta.pdf(.4,4,2)
arange
# Out:
# 0.7679999999999999

# %%
x=np.linspace(0,1,1000)
y=[st.beta.pdf(val,4,2) for val in x]

# %%
sns.distplot(pts)
plt.plot(x,y)
